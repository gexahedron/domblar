# %%
from matplotlib.pyplot import imshow, figure
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
pil_im = Image.open('elia/elia2.png', 'r')
im_np = np.array(pil_im)
print(im_np.shape)
start = 30
step = 26
for i in range(start, im_np.shape[1], step):
    im_np[:, i, :] = [1, 1, 0, 1]
figure(figsize = (13, 13))
imshow(im_np)
# Out:
# (1362, 1474, 4)
