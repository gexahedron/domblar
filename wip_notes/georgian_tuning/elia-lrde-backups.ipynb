# %%
# class PyoEngine:
#     def __init__(self):
#         self.server = pyo.Server().boot()
#         self.server.start()
#         self.server.amp = 0.8
#         # single white noise
#         self.noise = pyo.Noise()
#         # denormal signal
#         self.denorm = self.noise * 1e-24
#         # little jitter around 1 used to modulate frequency
#         self.jitter = self.noise * 0.0007 + 1.0
#         # excitation signal of the waveguide
#         self.source = self.noise * 0.7

#     def play_chord(self, notes, loudness=0.4, duration=0.7):
#         chord = []

#         for idx, freq in enumerate(notes):
#             env = pyo.Fader(fadein=0.001, fadeout=0.01, dur=0.015).play()
#             src = pyo.ButLP(self.source, freq=440, mul=env * loudness)
#             sound = pyo.Waveguide(src + self.denorm, freq=freq * self.jitter, dur=duration)
#             chord.append(pyo.Pan(sound, pan=0.5).out())
#         time.sleep(duration)

# %%
chords = []
# solo of second voice
# 0
chords.append(Chord(0.78, [None, 2727, None], 'e'))
chords.append(Chord(1.98, [None, 2545, None], 'lya'))
chords.append(Chord(2.38, [None, 2409, None], 'lar'))
chords.append(Chord(2.80, [None, 2225, None], 'de'))
chords.append(Chord(3.47, [None, 2565, None], 'i'))
chords.append(Chord(5.20, [None, 2407, None], 'la'))

# first verse
# 6
chords.append(Chord(5.66, [2022, 384, 702], 'la'))
chords.append(Chord(7.57, [2051, 454, 676], 'i/qi'))
chords.append(Chord(8.34, [None, None, 2727], 'i'))
chords.append(Chord(9.18, [2025, 457, 703], 'le/me'))
chords.append(Chord(10.07, [2086, 421, 671], 'i'))
chords.append(Chord(10.59, [2039, 436, 688], 'a'))
chords.append(Chord(11.03, [1785, 558, 828], 'uo'))
chords.append(Chord(11.53, [1516, 906, None], 'o'))
chords.append(Chord(11.99, [1660, 410, 747], 'le'))
chords.append(Chord(13.47, [1860, 532, 713], 'si'))
chords.append(Chord(14.17, [1837, 433, 763], 'a'))
chords.append(Chord(14.87, [2053, 30, 36], 'uo'))
# so, actually, they have tolerance of 30 cents
# when they sing the same note
# or the lowest voice has a bigger tolerance, than higher voices

# second verse
# 18
chords.append(Chord(16.91, [2061, 479, 710], 'a/sa'))
chords.append(Chord(18.28, [2062, 502, 713], 'i'))
chords.append(Chord(19.07, [2062, None, 716], 'i/a'))
chords.append(Chord(19.86, [2011, 524, 767], 'a/da'))
chords.append(Chord(21.19, [2053, 348, 734], 'a/ma/ua'))
chords.append(Chord(21.85, [1822, 416, 865], 'a'))
chords.append(Chord(22.69, [1713, 840, 1166], 'ki'))
chords.append(Chord(23.60, [1713, 840, 1166], 'ri'))
chords.append(Chord(23.97, [1655, 713, 1113], 'o/a'))
chords.append(Chord(24.58, [1604, 596, 1043], 'uo/a'))
chords.append(Chord(24.99, [None, 2215+111, -111], 'o/a'))
chords.append(Chord(25.47, [1651, 414, 723], 'le'))
chords.append(Chord(27.10, [1863, 507, 854], 'si/ri'))
chords.append(Chord(27.73, [1842, 383, 705], 'a'))
chords.append(Chord(28.40, [2062, 4, 6], 'uo'))
# here they have better sync

# third verse
# 33
chords.append(Chord(30.41, [2028, 491, 734], 'kra'))
chords.append(Chord(32.21, [2030, 538, 766], 'si'))
chords.append(Chord(32.81, [1686, 677, 1072], 'uo'))
chords.append(Chord(33.34, [1686, 677, 670], 'uo/o'))
chords.append(Chord(33.98, [1834, 362, 710], 'de/re'))
# 38
chords.append(Chord(35.18, [2020, 513, 732], 'kra'))
chords.append(Chord(36.71, [2011, 564, 730], 'si'))
chords.append(Chord(37.20, [1683, 705, 709], 'uo'))
chords.append(Chord(38.34, [1795, 431, 751], 'de/le'))
# 42
chords.append(Chord(39.30, [2006, 502, 716], 'a'))
chords.append(Chord(39.97, [2039, 530, 714], 'li/i'))
chords.append(Chord(40.41, [2016, 366, 720], 'a/gha'))
chords.append(Chord(40.89, [2037, 533, 727], 'li/i'))
chords.append(Chord(41.51, [2028, 518, 720], 'me/ma'))
chords.append(Chord(42.24, [2083, 500, 679], 'i'))
chords.append(Chord(42.47, [2065, 325, 650], 'a'))
# next chord: is it a real one?
chords.append(Chord(42.95, [1784, 465, 773], 'uo'))
chords.append(Chord(43.16, [1515, 735, 1043], 'uo/o'))
chords.append(Chord(43.59, [1674, 408, 719], 'lo/le'))
chords.append(Chord(44.84, [1884, 516, 657], 'si/li'))
chords.append(Chord(45.26, [1874, 390, 680], 'a'))
chords.append(Chord(45.88, [2062, 10, 11], 'uo'))

# fourth verse
# 55
chords.append(Chord(47.98, [2055, 488, 684], 'so/sa'))
chords.append(Chord(49.38, [2069, 500, 682], 'li'))
chords.append(Chord(50.77, [2043, 498, 704], 'a/da/ma'))
chords.append(Chord(52.36, [2066, 337, 712], 'ma/ua'))
chords.append(Chord(52.95, [1884, 348, 779], 'a'))
chords.append(Chord(53.80, [1680, 877, 1199], 'ki'))
chords.append(Chord(54.87, [1713, 860, 1192], 'ri'))
chords.append(Chord(55.35, [1663, 697, 1088], 'a'))
# the next one is a bit questionable, but let's stick to this interpretation
# intervals: 1663+567-1635=595, 1663+963-1635=991
chords.append(Chord(55.97, [1635, 1663+567-1635, 1663+963-1635], 'uo/ra/lol'))
chords.append(Chord(56.28, [1635, 701, 577], 'le/a/lol'))
chords.append(Chord(56.76, [1682, 385, 693], 'le/me'))
chords.append(Chord(58.65, [1882, 524, 837], 'si/li'))
chords.append(Chord(59.34, [1855, 414, 726], 'a'))
chords.append(Chord(60.15, [2078, -8, -5], 'uo'))

# chords.append(Chord(8.34,  ch([None, None, 2727]), [None, None, 2747], 'i'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5da22665f474> in <module>
#       2 # solo of second voice
#       3 # 0
# ----> 4 chords.append(Chord(0.78, [None, 2727, None], 'e'))
#       5 chords.append(Chord(1.98, [None, 2545, None], 'lya'))
#       6 chords.append(Chord(2.38, [None, 2409, None], 'lar'))
#
# NameError: name 'Chord' is not defined

# %%
el = wave.open('/Users/a1111/Downloads/svan tuning/elialrde/elialrde_mono.wav', 'rb')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8a34b3edfdce> in <module>
# ----> 1 el = wave.open('/Users/a1111/Downloads/svan tuning/elialrde/elialrde_mono.wav', 'rb')
#
# NameError: name 'wave' is not defined

# %%
# chord_idxs = [33, 34, 35, 36, 37]
chord_idxs = []
for chord_idx in chord_idxs:
    print(chords[chord_idx])
    start = chords[chord_idx].timestamp
    n_frames = int(start * el.getframerate())
    el.setpos(n_frames)
    length = chords[chord_idx + 1].timestamp - start
    n_frames = int(length * el.getframerate())
    frames = el.readframes(n_frames)

    py_audio = pyaudio.PyAudio()
    stream = py_audio.open(format=py_audio.get_format_from_width(el.getsampwidth()),
                           channels=el.getnchannels(),
                           rate=el.getframerate(),
                           output=True)

    ref_hz = 110
    pitches = []
    ref = None
    for cents in chords[chord_idx].chord:
        if cents is not None:
            if ref is None:
                ref = cents
                pitch = ref
            else:
                pitch = ref + cents
            pitches.append(pitch)

    hzs = [calc_hz(pitch, ref_hz) for pitch in pitches]

    def func1():
        engine.play_chord(hzs, duration=length, loudness=3)

    def func2():
        stream.write(frames)
        stream.close()

    t1 = Thread(target = func1)
    t2 = Thread(target = func2)
    t1.start()
    t2.start()
    t1.join()
    t2.join()

# %%
    retuned_pitch_pairs = []
    for p in pitches:
        best_r = [None, None]
        for r in retuned_cents:
            if r <= p:
                ind = 0
            else:
                ind = 1
            ind = 0 # fixme
            #if abs(r - p) < 70 and\
            if (best_r[ind] is None or abs(r - p) < abs(best_r[ind] - p)):
                best_r[ind] = r
        retuned_pitch_pairs.append(best_r)

    best_mask = None
    best_diff = None
    best_mxmn = None
    retuned_pitches = []
    for mask in range(8):
        selection = []
        has_none = False
        for p_i, p in enumerate(pitches):
            ind = 0
            if mask & (1 << p_i) > 0:
                ind = 1
            r = retuned_pitch_pairs[p_i][ind]
            if r is None:
                has_none = True
                break
            selection.append(r)
        if has_none:
            continue
        diff = np.array(selection) - pitches
        if len(diff) == 1:
            mxmn = abs(diff[0])
        else:
            mxmn = np.max(diff) - np.min(diff)
        if best_mxmn is None or mxmn < best_mxmn:
            best_mask = mask
            retuned_pitches = selection
            best_diff = diff
            best_mxmn = mxmn
    diff = best_diff
    mxmn = best_mxmn
#     diff = np.array(retuned_pitches) - pitches
#     mxmn = np.max(diff) - np.min(diff)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-13ee3ab35587> in <module>
#       1 retuned_pitch_pairs = []
# ----> 2 for p in pitches:
#       3     best_r = [None, None]
#       4     for r in retuned_cents:
#       5         if r <= p:
#
# NameError: name 'pitches' is not defined

# %%
main_pitch_in_cents = 2060

# retuned_cents = [-551, -455, -385, -279, -209, -183, -51, -26,
#                  0, 157, 175, 202, 271, 315, 359,
#                  429, 491, 517, 561, 605, 674,
#                  701, 832]
# retuned_cents = np.array(retuned_cents) + main_pitch_in_cents
# retuned_cents = [r.item() for r in retuned_cents]
# print(retuned_cents)

retuned_cents = [1512, 1672, 1863, 2057, 2245, 2419, 2549, 2737, 2887] +\
                [2343]

retuned_hz = []
for p in retuned_cents:
    pitch_in_hz = calc_hz(p, ref_hz)
    retuned_hz.append(pitch_in_hz)

voice = None
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-e58fbfee09df> in <module>
#      14 retuned_hz = []
#      15 for p in retuned_cents:
# ---> 16     pitch_in_hz = calc_hz(p, ref_hz)
#      17     retuned_hz.append(pitch_in_hz)
#      18
#
# NameError: name 'calc_hz' is not defined

# %%
#     if (0 <= idx <= 16):
#         continue
#     if not (54 <= idx):
#         continue

#     pitches = []
#     pitches_with_none = []
#     ref = None
#     for pitch in cur_chord:
#         pitches_with_none.append(pitch)
#         if pitch is not None:
#             pitches.append(pitch)

#     if voice is not None:
#         if pitches_with_none[voice] is None:
#             time.sleep(sleep_time)
#             continue
#         else:
#             pitches = [pitches_with_none[voice]]

#     r_shf = np.array(retuned_pitches)# - main_pitch_in_cents
#     p_shf = np.array(pitches)# - main_pitch_in_cents
#     print(chord.syllable, r_shf, p_shf, diff)
#     if mxmn > 36:
#     if mxmn > 40:
#         print(chord.syllable, r_shf, p_shf, diff)
#         print('!!!DIFF:', mxmn)
#     continue

# %%
#     tolerance = 50
#                 if abs(chord.redux[i] - chord.chord[i]) > tolerance:
#                     print('high tol!', chord, abs(chord.redux[i] - chord.chord[i]), tolerance)
#                 assert(abs(chord.redux[i] - chord.chord[i]) <= tolerance)

# %%
cents_tolerance = 100 / 8

ref_hz = 55

main_pitch_in_hz = calc_hz(main_pitch_in_cents, ref_hz)

ret_sort = sorted(retuned_cents)
ret_sort = np.array(ret_sort) - main_pitch_in_cents
print(ret_sort)
prev_chord = [[None] * 3, [None] * 3]
melsteps = [defaultdict(int), defaultdict(int), defaultdict(int)]
all_melsteps = defaultdict(int)
intervals = [defaultdict(int), defaultdict(int), defaultdict(int)]
intervals_as_ji = dict()
for chord in chords:
    cur_chord = chord.chord
    pitches = []
    pitches_with_none = []
    ref = None
    for i, cents in enumerate(cur_chord):
        if cents is not None:
            if ref is None:
                ref = cents
                pitch = ref
            else:
                pitch = ref + cents
            p = pitch - main_pitch_in_cents
            pitches.append(p)
            pitches_with_none.append(p)
        else:
            pitches_with_none.append(None)

    retuned_pitches = []
    retuned_pitches_with_none = []
    for p in pitches_with_none:
        if p is None:
            retuned_pitches_with_none.append(None)
            continue
        best_r = None
        for r in ret_sort:
            if best_r is None or abs(r - p) < abs(best_r - p):
                best_r = r
        retuned_pitches.append(best_r)
        retuned_pitches_with_none.append(best_r)
    print(chord.syllable, retuned_pitches_with_none, 'orig:', pitches)
    
    pitches_to_analyze = [retuned_pitches_with_none, pitches_with_none]
    all_pitches_in_cents_with_none = []
    
    for p_idx, pitches in enumerate(pitches_to_analyze):
        pitches_in_hz = []
        pitches_in_cents = []
        pitches_in_cents_with_none = []
        for pitch in pitches:
            if pitch is None:
                pitches_in_cents_with_none.append(None)
                continue
            pitch_in_hz = calc_hz(pitch, main_pitch_in_hz)
            pitches_in_hz.append(pitch_in_hz / main_pitch_in_hz)
            pitch_in_cents = int(ratio_to_cents(pitch_in_hz, main_pitch_in_hz))
            pitches_in_cents.append(pitch_in_cents)
            pitches_in_cents_with_none.append(pitch_in_cents)
        all_pitches_in_cents_with_none.append(pitches_in_cents_with_none)
        
        # chord intervals
        if len(pitches_in_cents) == 1:
            diffs = []
        elif len(pitches_in_cents) == 2:
            diffs = [pitches_in_cents[1] - pitches_in_cents[0]]
        else:
            diffs = [pitches_in_cents[2] - pitches_in_cents[0],
                     pitches_in_cents[2] - pitches_in_cents[1],
                     pitches_in_cents[1] - pitches_in_cents[0]]
            if p_idx == 1:
                for k in range(3):
                    intervals[k][diffs[k]] += 1
        diffs = [abs(c) for c in diffs]
        # print(diffs)
        notes = []
        for i, p in enumerate(diffs):
            n = str(diffs[i]) + 'c'
            state = ''
            for r in ratios:
                c1 = diffs[i]
                c2 = ratio_to_cents(r[0], r[1])
                check1 = abs(c1 - c2) < cents_tolerance
                check2 = abs(c1 - c2) < cents_tolerance * 1.5
                add = ''
                if check2 and not check1:
                    add = '?'
                if check2:
                    if r == (1, 1):
                        state = '.' + add
                    else:
                        state = 'ji'
                        n += ' ' + add + str(r[0]) + '/' + str(r[1])
            notes.append((n, state))
#         print(' ' * p_idx * 4 + chord.syllable, notes)
        if p_idx == 1:
            if len(diffs) == 3:
                for k in range(3):
                    pretty = ' '.join(notes[k][0].split(' ')[1:])
                    intervals_as_ji[diffs[k]] = pretty + ' ' + notes[k][1]
        mel_diff = []
        for j, p in enumerate(pitches_in_cents_with_none):
            if prev_chord[p_idx][j] is None or p is None:
                mel_diff.append(None)
            else:
                step = p - prev_chord[p_idx][j]
                if p_idx == 1:
                    melsteps[j][abs(step)] += 1
                    all_melsteps[abs(step)] += 1
                mel_diff.append(step)
        if p_idx == 1:
            print(' ' * p_idx * 4 + '  melstep', mel_diff)
    prev_chord = all_pitches_in_cents_with_none

for i in range(3):
    print(i)
    for k in sorted(intervals[i].keys()):
        print(k, intervals[i][k], intervals_as_ji[abs(k)])
    print()

#     print(i, json.dumps(intervals[i], indent=4, sort_keys=True))
# for i in range(3):
#     print(i, json.dumps(melsteps[i], indent=4, sort_keys=True))
# print('all', json.dumps(all_melsteps, indent=4, sort_keys=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-cb3da3064b0d> in <module>
#       3 ref_hz = 55
#       4
# ----> 5 main_pitch_in_hz = calc_hz(main_pitch_in_cents, ref_hz)
#       6
#       7 ret_sort = sorted(retuned_cents)
#
# NameError: name 'calc_hz' is not defined

# %%
cents_tolerance = 100 / 8
ref_hz = 55
main_pitch_in_hz = calc_hz(main_pitch_in_cents, ref_hz)
voice = 1
prev_pitch = None
for chord in chords:
    pitches = []
    ref = None
    for i, cents in enumerate(chord.chord):
        if cents is not None:
            if ref is None:
                ref = cents
                pitch = ref
            else:
                pitch = ref + cents
            p = pitch - main_pitch_in_cents
            pitches.append(p)
        else:
            pitches.append(None)
#     print(chord.syllable, pitches[voice])
    if pitches[voice] is None:
        continue
    if prev_pitch is None:
        prev_pitch = pitches[voice]
        print(chord.syllable, 'None', pitches[voice])
        continue
    
    pitches_in_hz = []
    pitches_in_cents = []
    pitches_in_cents_with_none = []
    pitch = pitches[voice]

    pitch_in_hz = calc_hz(pitch, main_pitch_in_hz)
    pitch_in_cents = int(ratio_to_cents(pitch_in_hz, main_pitch_in_hz))
    mel_diff = pitch - prev_pitch
    print(chord.syllable, mel_diff, pitches[voice])
    prev_pitch = pitches[voice]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a05aeae50e69> in <module>
#       1 cents_tolerance = 100 / 8
#       2 ref_hz = 55
# ----> 3 main_pitch_in_hz = calc_hz(main_pitch_in_cents, ref_hz)
#       4 voice = 1
#       5 prev_pitch = None
#
# NameError: name 'calc_hz' is not defined
